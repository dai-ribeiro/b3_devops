# %% [markdown]
# Q01 - Leia a declaração abaixo e assinale a opção concordando com ela.
#
# Assumo o compromisso de realizar a prova sem auxílio externo, contato com outras pessoas ou cópia de códigos da internet. Consultarei apenas o meu material pessoal e o material de aula disponibilizado pela Ada e pelo professor.
#
# Estou ciente que o não-cumprimento das regras pode causar o desligamento do processo seletivo.

# %% [markdown]
# Q02 - O circuito abaixo possui dois resistores ligados em paralelo, R1 e R2.
#
#
#
# Eles podem ser substituídos por um único resistor com um valor específico, conhecido por resistor equivalente, que fará circular a mesma corrente por ele.
#
# O valor da resistência equivalente é dado pela fórmula:
#
#
#
# O valor da corrente é dado por:
#
#
#
# Onde U é a tensão da fonte de alimentação.
#
# Faça um programa que pergunta o valor da tensão de uma bateria e de dois resistores em paralelo e responde a resistência equivalente do circuito e o valor da corrente que fluirá por ele.

# %%
tensao = float(input('digite o valor da tensão: '))
resistor1 = float(input('digite o valor do resistor1: '))
resistor2 = float(input('digite o valor do resistor2: '))

req = (resistor1 * resistor2) / (resistor1 + resistor2)

corrente = tensao / req

print(f'Resistência equivalente: {req} | Corrente: {corrente}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22676/942631195.py in <module>
# ----> 1 tensao = float(input('digite o valor da tensão: '))
#       2 resistor1 = float(input('digite o valor do resistor1: '))
#       3 resistor2 = float(input('digite o valor do resistor2: '))
#       4
#       5 req = (resistor1 * resistor2) / (resistor1 + resistor2)
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# Q03 - Considere o código em Python abaixo:
#
# for x in range(1, 30):
#
#     if x % 2 == 0 and x % 10 == 0:
#
#         comando1
#
#     if x % 3 == 0 and x % 4 == 0:
#
#         comando2
#
#     if x % 3 == 0 and x % 11 == 0:
#
#         comando3
#
# Qual ou quais comandos não serão executados?

# %%
for x in range(1, 30):
    if x % 2 == 0 and x % 10 == 0:
        print('abestado')
    if x % 3 == 0 and x % 4 == 0:
        print('banana')
    if x % 3 == 0 and x % 11 == 0:
        print('minion')
# Out:
# abestado
# banana
# abestado
# banana

# %% [markdown]
# Q04 - No jogo jokenpo, também conhecido como pedra-tesoura-papel, dois jogadores devem anunciar ao mesmo tempo sua jogada. As jogadas podem ser pedra, tesoura ou papel.
#
# O vencedor será dado pela relação entre as jogadas de ambos:
#
# Pedra quebra a tesoura
#
# Tesoura corta o papel
#
# Papel embrulha a pedra
#
# Faça um programa que pede para o usuário digitar uma das 3 opções (pedra, tesoura ou papel). Em seguida, seu programa deverá sortear uma jogada aleatória para o computador. Seu programa deverá imprimir na tela a jogada do computador e o resultado:
#
# "Você venceu!"
#
# "Voce perdeu!"
#
# "Empate!"
#
# Para ajudá-la, lembre-se:
#
# As linhas abaixo sorteiam um número aleatório entre 0 e 2 (incluindo 0 e 2) e a salvam na varíavel sorteio:
#
# import random
#
# sorteio = random.randint(0, 2)

# %%
import random

sorteio = random.randint(0, 2)
# print(sorteio)
escolhas = ['pedra', 'papel', 'tesoura']

opcao = int(input('Escolha uma opcao (0-pedra, 1-papel, 2-tesoura: '))

if opcao == sorteio:
    print(f'O computador escolheu: {escolhas[sorteio]} | Empate!')
elif (sorteio == 0) and (opcao == 2):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você perdeu!')
elif (sorteio == 0) and (opcao == 1):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você venceu!')
elif (sorteio == 1) and (opcao == 0):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você perdeu!')
elif (sorteio == 1) and (opcao == 2):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você venceu!')
elif (sorteio == 2) and (opcao == 1):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você perdeu!')
elif (sorteio == 2) and (opcao == 0):
    print(f'O computador escolheu: {escolhas[sorteio]} | Você venceu!')
# Out:
# 1
# O computador escolheu: papel | Você venceu!

# %% [markdown]
# Q05 - O valor da raiz quadrada de um número positivo x pode ser aproximado pelo método da bissecção. Ele funciona da seguinte maneira:
#
# Escolha 2 números, i e f, tal que a raiz quadrada de x com certeza esteja contida no intervalo [i, f].
# Escolha a precisão e desejada.
# Enquanto f - i for maior do que e, repita os seguintes passos:
# - Encontre o valor "m" que representa o meio do intervalo.
# - Se m² > x, "f" recebe "m". Caso contrário, "i" recebe "m".
# A precisão e tipicamente é um número bem pequeno, como 0.0001 ou 0.00001.
#
# Implemente um programa que pede para o usuário digitar um número e a precisão aceitável.
#
# Seu programa deverá calcular e responder a raiz quadrada com a precisão desejada utilizando o método da bissecção.

# %%
x = int(input('Informe o valor de x: '))
e = float(input('Informe a precisão (0.0001 ou 0.00001) : '))

i = x - (x-1)
f = x

while (f - i) > e:
    m = (f + i) / 2
    if m**2 > x:
        f = m
    else:
        i = m
else:
    print(f'Média: {m}')
# Out:
# Média 5.000030517578125

# %% [markdown]
# Q06 - Em estatística, frequentemente descrevemos um conjunto de amostras utilizando alguma medida de tendência central, como a média ou a mediana, e uma medida de dispersão, como a variância ou o desvio padrão.
#
# A variância pode ser calculada pela fórmula:
#
# Onde:
#
# - vi é cada uma das amostras em uma lista "v" (v[0], v[1], v[2] etc)
# - md é a média
# - n é o número de amostras (o tamanho da lista "v")
# - a letra grega sigma representa o somatório.
#
# Ou seja, deve-se somar: (v[0]-md)^2 + (v[1]-md)^2 + (v[2]-md)^3, e assim sucessivamente, e no final divide-se o resultado por n-1.
#
# Faça um programa que pergunta quantos alunas o professor tem. Em seguida, leia as notas de todas as alunas pelo teclado.
#
# O programa deverá exibir a média e a variância das notas da turma na tela.
#
# Sugestão de teste:
#
# A lista [9, 1, 8, 2, 7, 3, 6, 4] possui média = 5.0 e variância = 8.57 (aproximadamente)

# %%
qtde = int(input('Quantas alunas: '))
notas = []
soma = 0

for i in range(qtde):
    nota = float(input(f'Digite a nota {i+1}:'))
    notas.append(nota)

media = sum(notas) / len(notas)

for v in range(len(notas)):
    soma += (notas[v] - media) ** 2

variancia = soma / (len(notas) - 1)

print(f'Média da turma = {media} | Variância = {variancia:.2f}')
# Out:
# [9.0, 1.0, 8.0, 2.0, 7.0, 3.0, 6.0, 4.0]
# Média da turma = 5.0 | Variância = 8.571428571428571

# %% [markdown]
# Q07 - A tabela SAC é uma alternativa à tabela Price. Ela também é utilizada para cálculo de prestações de empréstimos, como financiamentos imobiliários.
#
# Ao contrário da tabela Price, ela não possui valor fixo de prestação. Ao invés disso ela possui valor fixo de amortização. Ou seja, amortiza-se o mesmo valor todo mês.
#
# Logo no início do cálculo podemos dividir o saldo devedor pelo número total de meses para obter o valor da amortização.
#
# Em cada mês, iremos aplicar a taxa de juros ao saldo devedor da mesma maneira que na tabela Price para descobrir quanto pagaremos de juros naquele mês. Em seguida, podemos somar taxa de juros e amortização (que é constante) para obter o valor da prestação. O novo saldo devedor é obtido subtraindo o valor amortizado, como na tabela Price.
#
# Faça um programa que pede a taxa de juros de um empréstimo, o valor emprestado e o prazo (em meses) para quitar o empréstimo.
#
# Seu programa deverá mostrar, mês a mês, o valor pago de juros, de amortização, o valor total da prestação e o saldo devedor.
#
# Este link ajudou vocês durante o curso para calcular uma tabela Price. Ele também explica as diferenças entre Price e SAC.

# %%
valor = float(input('Qual é o valor do empréstimo? '))
taxa_juros = float(input('Qual é a taxa de juros? ')) / 100
tempo = int(input('Qual é o tempo em meses? '))
amortizacao = valor / tempo
juros = 0
parcela = 0
saldo = valor

for n in range(1, tempo+1):
    juros = saldo * taxa_juros
    parcela = juros + amortizacao
    saldo -= amortizacao
    
    print(f'Parcela: {n} | Juros: {juros:.2f} | Amortização: {amortizacao:.2f} | Valor da prestação: {parcela:.2f} | Saldo devedor: {saldo:.2f}')
# Out:
# Parcela: 1 | Juros: 100.00 | Amortização: 833.33 | Valor da prestação: 933.33 | Saldo devedor: 9166.67
# Parcela: 2 | Juros: 91.67 | Amortização: 833.33 | Valor da prestação: 925.00 | Saldo devedor: 8333.33
# Parcela: 3 | Juros: 83.33 | Amortização: 833.33 | Valor da prestação: 916.67 | Saldo devedor: 7500.00
# Parcela: 4 | Juros: 75.00 | Amortização: 833.33 | Valor da prestação: 908.33 | Saldo devedor: 6666.67
# Parcela: 5 | Juros: 66.67 | Amortização: 833.33 | Valor da prestação: 900.00 | Saldo devedor: 5833.33
# Parcela: 6 | Juros: 58.33 | Amortização: 833.33 | Valor da prestação: 891.67 | Saldo devedor: 5000.00
# Parcela: 7 | Juros: 50.00 | Amortização: 833.33 | Valor da prestação: 883.33 | Saldo devedor: 4166.67
# Parcela: 8 | Juros: 41.67 | Amortização: 833.33 | Valor da prestação: 875.00 | Saldo devedor: 3333.33
# Parcela: 9 | Juros: 33.33 | Amortização: 833.33 | Valor da prestação: 866.67 | Saldo devedor: 2500.00
# ...
